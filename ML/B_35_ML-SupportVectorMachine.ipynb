# %% [markdown]
# # SUPPORT VECTOR MACHINE (SVM)-CLASSIFICATION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
data = pd.read_csv(r'C:\Users\User\juypter\files\placement1.csv')
data.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
data.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
sns.scatterplot(x="cgpa",y="resume_score",data=data,hue="placed")
plt.show()

# %%
x = data.iloc[:,:-1]
x.ndim
y = data["placed"]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVC

sv = SVC(kernel="linear")
sv.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
sv.score(x_train,y_train)*100,sv.score(x_test,y_test)*100
# Out:
# (97.5, 100.0)

# %%
import matplotlib.pyplot as plt
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv)
plt.xlabel('X1')    
plt.ylabel('X2')
plt.title('SVM (Test Data)')
plt.show()
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
kernel = 'linear','poly','rbf','sigmoid','prcomuputed'

# %%
from sklearn.svm import SVC

sv1 = SVC(kernel='poly')
sv1.fit(x_train, y_train)
# Out:
# SVC(kernel='poly')

# %%
sv1.score(x_train,y_train)*100,sv.score(x_test,y_test)*100
# Out:
# (96.25, 100.0)

# %%
import matplotlib.pyplot as plt
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv1)
plt.xlabel('X1')    
plt.ylabel('X2')
plt.title('SVM (Test Data)')
plt.show()
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
from sklearn.svm import SVC

sv2 = SVC(kernel='rbf')
sv2.fit(x_train, y_train)
# Out:
# SVC()

# %%
sv2.score(x_train,y_train)*100,sv.score(x_test,y_test)*100
# Out:
# (96.25, 100.0)
