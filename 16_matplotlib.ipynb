# %%
import matplotlib.pyplot as plt
import numpy as np

# text function,annotation

plt.plot([10,20,30,40],marker="o")
plt.annotate("point",(0,10),(0.5,25),size=10,color="green",arrowprops={"width":10},annotation_clip=False)

# "arrowstyle":"<->"}

plt.show()
