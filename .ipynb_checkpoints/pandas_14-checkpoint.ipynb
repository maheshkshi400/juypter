# %%
import pandas as pd

df= pd.read_csv('people-1000.csv')
df
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
df.replace(to_replace=0,value=5)
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
df.replace(to_replace="Lee",value="python")
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e     python      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
df.replace("[a-z]","python",regex=True)
# Out:
#      Index                                            User Id  \
# 0        1      8717pythonpythonpython45pythonCDpythonEpython
# 1        2                3python5AD30A4pythonD38pythonpython
# 2        3           810Cpython0F276Bpythonpythonpythonpython
# 3        4                     BF2python889C00python0pythonE1
# 4        5           9pythonpythonFEpythonpythonApython1CBBB9
# ..     ...                                                ...
# 995    996  pythonpythonpythonF4python7Fpython9python7pyth...
# 996    997           ECpythonpythonpythonFEDpythonEpython4FAB
# 997    998           2pythonpythonpythonpython51python8B8979E
# 998    999                               Fpython2FE369D1E171A
# 999   1000                     8python756python6231DDC6python
#
#                                       First Name  \
# 0                Spythonpythonpythonpythonpython
# 1                                        Jpython
# 2                Spythonpythonpythonpythonpython
# ...

# %%
df.replace({"Email":'[a-z]'},22,regex=True)
# Out:
#      Index          User Id First Name Last Name     Sex  Email  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male     22
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female     22
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female     22
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male     22
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female     22
# ..     ...              ...        ...       ...     ...    ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female     22
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female     22
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female     22
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male     22
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female     22
#
#                      Phone Date of birth                        Job Title
# 0             857.139.8239    2014-01-27                Probation officer
# ...

# %%
import pandas as pd

df2= pd.read_csv('empdf.CSV')
df2
# Out:
#      id     name  gender   age   salary     dept  deptno     doj
# 0   1.0   mahesh    male  20.0   5000.0       IT    50.0  2002.0
# 1   2.0  shruthi  female   NaN   6000.0       HR    20.0  2008.0
# 2   3.0   ganesh    male  25.0   7000.0  FINANCE    30.0  2010.0
# 3   4.0    pooja  female   NaN   8000.0  PAYROLL    40.0  2005.0
# 4   5.0   kamini  female  31.0   6000.0       IT    50.0  2007.0
# 5   NaN      NaN     NaN   NaN      NaN      NaN     NaN     NaN
# 6   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 7   8.0   suresh    male  25.0  10000.0  FINANCE    30.0  2011.0
# 8   9.0  shivani  female  34.0      NaN  PAYROLL    40.0  2013.0
# 9  10.0   prachi  female  30.0   6000.0       IT    50.0  2001.0

# %%
df2.interpolate()
# Out:
#      id     name  gender   age   salary     dept  deptno     doj
# 0   1.0   mahesh    male  20.0   5000.0       IT    50.0  2002.0
# 1   2.0  shruthi  female  22.5   6000.0       HR    20.0  2008.0
# 2   3.0   ganesh    male  25.0   7000.0  FINANCE    30.0  2010.0
# 3   4.0    pooja  female  28.0   8000.0  PAYROLL    40.0  2005.0
# 4   5.0   kamini  female  31.0   6000.0       IT    50.0  2007.0
# 5   6.0      NaN     NaN  30.5   6000.0      NaN    35.0  2002.5
# 6   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 7   8.0   suresh    male  25.0  10000.0  FINANCE    30.0  2011.0
# 8   9.0  shivani  female  34.0   8000.0  PAYROLL    40.0  2013.0
# 9  10.0   prachi  female  30.0   6000.0       IT    50.0  2001.0

# %%
df2.interpolate(method='linear')
# Out:
#      id     name  gender   age   salary     dept  deptno     doj
# 0   1.0   mahesh    male  20.0   5000.0       IT    50.0  2002.0
# 1   2.0  shruthi  female  22.5   6000.0       HR    20.0  2008.0
# 2   3.0   ganesh    male  25.0   7000.0  FINANCE    30.0  2010.0
# 3   4.0    pooja  female  28.0   8000.0  PAYROLL    40.0  2005.0
# 4   5.0   kamini  female  31.0   6000.0       IT    50.0  2007.0
# 5   6.0      NaN     NaN  30.5   6000.0      NaN    35.0  2002.5
# 6   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 7   8.0   suresh    male  25.0  10000.0  FINANCE    30.0  2011.0
# 8   9.0  shivani  female  34.0   8000.0  PAYROLL    40.0  2013.0
# 9  10.0   prachi  female  30.0   6000.0       IT    50.0  2001.0

# %%
df2.interpolate(limit_direction='forward',limit=2)
# Out:
#      id     name  gender   age   salary     dept  deptno     doj
# 0   1.0   mahesh    male  20.0   5000.0       IT    50.0  2002.0
# 1   2.0  shruthi  female  22.5   6000.0       HR    20.0  2008.0
# 2   3.0   ganesh    male  25.0   7000.0  FINANCE    30.0  2010.0
# 3   4.0    pooja  female  28.0   8000.0  PAYROLL    40.0  2005.0
# 4   5.0   kamini  female  31.0   6000.0       IT    50.0  2007.0
# 5   6.0      NaN     NaN  30.5   6000.0      NaN    35.0  2002.5
# 6   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 7   8.0   suresh    male  25.0  10000.0  FINANCE    30.0  2011.0
# 8   9.0  shivani  female  34.0   8000.0  PAYROLL    40.0  2013.0
# 9  10.0   prachi  female  30.0   6000.0       IT    50.0  2001.0
