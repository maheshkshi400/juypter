# %%
import pandas as pd


df = pd.read_csv('empdf.csv')
df
# Out:
#      id     name  gender   age   salary     dept  deptno     doj
# 0   1.0   mahesh    male  20.0   5000.0       IT    50.0  2002.0
# 1   2.0  shruthi  female   NaN   6000.0       HR    20.0  2008.0
# 2   3.0   ganesh    male  25.0   7000.0  FINANCE    30.0  2010.0
# 3   4.0    pooja  female   NaN   8000.0  PAYROLL    40.0  2005.0
# 4   5.0   kamini  female  31.0   6000.0       IT    50.0  2007.0
# 5   NaN      NaN     NaN   NaN      NaN      NaN     NaN     NaN
# 6   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 7   8.0   suresh    male  25.0  10000.0  FINANCE    30.0  2011.0
# 8   9.0  shivani  female  34.0      NaN  PAYROLL    40.0  2013.0
# 9  10.0   prachi  female  30.0   6000.0       IT    50.0  2001.0

# %%
df.fillna(12,inplace=True)
df
# Out:
#      id     name  gender   age   salary     dept  deptno     doj
# 0   1.0   mahesh    male  20.0   5000.0       IT    50.0  2002.0
# 1   2.0  shruthi  female  12.0   6000.0       HR    20.0  2008.0
# 2   3.0   ganesh    male  25.0   7000.0  FINANCE    30.0  2010.0
# 3   4.0    pooja  female  12.0   8000.0  PAYROLL    40.0  2005.0
# 4   5.0   kamini  female  31.0   6000.0       IT    50.0  2007.0
# 5  12.0       12      12  12.0     12.0       12    12.0    12.0
# 6   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 7   8.0   suresh    male  25.0  10000.0  FINANCE    30.0  2011.0
# 8   9.0  shivani  female  34.0     12.0  PAYROLL    40.0  2013.0
# 9  10.0   prachi  female  30.0   6000.0       IT    50.0  2001.0

# %%
df.fillna("python",limit=13)
# Out:
#      id     name  gender   age   salary     dept  deptno     doj
# 0   1.0   mahesh    male  20.0   5000.0       IT    50.0  2002.0
# 1   2.0  shruthi  female  12.0   6000.0       HR    20.0  2008.0
# 2   3.0   ganesh    male  25.0   7000.0  FINANCE    30.0  2010.0
# 3   4.0    pooja  female  12.0   8000.0  PAYROLL    40.0  2005.0
# 4   5.0   kamini  female  31.0   6000.0       IT    50.0  2007.0
# 5  12.0       12      12  12.0     12.0       12    12.0    12.0
# 6   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 7   8.0   suresh    male  25.0  10000.0  FINANCE    30.0  2011.0
# 8   9.0  shivani  female  34.0     12.0  PAYROLL    40.0  2013.0
# 9  10.0   prachi  female  30.0   6000.0       IT    50.0  2001.0

# %%
df.fillna(method='bfill',axis=1)
# Out:
#      id     name  gender     age   salary     dept deptno     doj
# 0   1.0   mahesh    male    20.0   5000.0       IT   50.0  2002.0
# 1   2.0  shruthi  female  6000.0   6000.0       HR   20.0  2008.0
# 2   3.0   ganesh    male    25.0   7000.0  FINANCE   30.0  2010.0
# 3   4.0    pooja  female  8000.0   8000.0  PAYROLL   40.0  2005.0
# 4   5.0   kamini  female    31.0   6000.0       IT   50.0  2007.0
# 5   NaN      NaN     NaN     NaN      NaN      NaN    NaN     NaN
# 6   7.0   shweta  female    30.0   6000.0       HR   20.0  1998.0
# 7   8.0   suresh    male    25.0  10000.0  FINANCE   30.0  2011.0
# 8   9.0  shivani  female    34.0  PAYROLL  PAYROLL   40.0  2013.0
# 9  10.0   prachi  female    30.0   6000.0       IT   50.0  2001.0

# %%
df.fillna({"name":"unnamed","gender":"unknown","salary":"NA"})
# Out:
#      id     name   gender   age   salary     dept  deptno     doj
# 0   1.0   mahesh     male  20.0   5000.0       IT    50.0  2002.0
# 1   2.0  shruthi   female   NaN   6000.0       HR    20.0  2008.0
# 2   3.0   ganesh     male  25.0   7000.0  FINANCE    30.0  2010.0
# 3   4.0    pooja   female   NaN   8000.0  PAYROLL    40.0  2005.0
# 4   5.0   kamini   female  31.0   6000.0       IT    50.0  2007.0
# 5   NaN  unnamed  unknown   NaN       NA      NaN     NaN     NaN
# 6   7.0   shweta   female  30.0   6000.0       HR    20.0  1998.0
# 7   8.0   suresh     male  25.0  10000.0  FINANCE    30.0  2011.0
# 8   9.0  shivani   female  34.0       NA  PAYROLL    40.0  2013.0
# 9  10.0   prachi   female  30.0   6000.0       IT    50.0  2001.0

# %%
df.fillna(method='ffill')
# Out:
#      id     name  gender   age   salary     dept  deptno     doj
# 0   1.0   mahesh    male  20.0   5000.0       IT    50.0  2002.0
# 1   2.0  shruthi  female  20.0   6000.0       HR    20.0  2008.0
# 2   3.0   ganesh    male  25.0   7000.0  FINANCE    30.0  2010.0
# 3   4.0    pooja  female  25.0   8000.0  PAYROLL    40.0  2005.0
# 4   5.0   kamini  female  31.0   6000.0       IT    50.0  2007.0
# 5   5.0   kamini  female  31.0   6000.0       IT    50.0  2007.0
# 6   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 7   8.0   suresh    male  25.0  10000.0  FINANCE    30.0  2011.0
# 8   9.0  shivani  female  34.0  10000.0  PAYROLL    40.0  2013.0
# 9  10.0   prachi  female  30.0   6000.0       IT    50.0  2001.0

# %%
df.fillna(method='bfill')
# Out:
#      id     name  gender   age   salary     dept  deptno     doj
# 0   1.0   mahesh    male  20.0   5000.0       IT    50.0  2002.0
# 1   2.0  shruthi  female  25.0   6000.0       HR    20.0  2008.0
# 2   3.0   ganesh    male  25.0   7000.0  FINANCE    30.0  2010.0
# 3   4.0    pooja  female  31.0   8000.0  PAYROLL    40.0  2005.0
# 4   5.0   kamini  female  31.0   6000.0       IT    50.0  2007.0
# 5   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 6   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 7   8.0   suresh    male  25.0  10000.0  FINANCE    30.0  2011.0
# 8   9.0  shivani  female  34.0   6000.0  PAYROLL    40.0  2013.0
# 9  10.0   prachi  female  30.0   6000.0       IT    50.0  2001.0
