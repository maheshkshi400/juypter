# %%
import matplotlib.pyplot as plt
import numpy as np

# text function

plt.plot([10,20,30,40],marker="o")
ax=plt.gca()

plt.text(0,0,"NOTE",transform=ax.transAxes,size=20,color="green")
print(plt.ylim())
plt.show()
# Out:
# (8.5, 41.5)
