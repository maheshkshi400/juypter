# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv(r'C:\Users\User\juypter\files\apple_products.csv')
data.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
data.isnull().sum()
# Out:
# Product Name           0
# Product URL            0
# Brand                  0
# Sale Price             0
# Mrp                    0
# Discount Percentage    0
# Number Of Ratings      0
# Number Of Reviews      0
# Upc                    0
# Star Rating            0
# Ram                    0
# dtype: int64

# %%
data.describe()
# Out:
#           Sale Price            Mrp  Discount Percentage  Number Of Ratings  \
# count      62.000000      62.000000            62.000000          62.000000
# mean    80073.887097   88058.064516             9.951613       22420.403226
# std     34310.446132   34728.825597             7.608079       33768.589550
# min     29999.000000   39900.000000             0.000000         542.000000
# 25%     49900.000000   54900.000000             6.000000         740.000000
# 50%     75900.000000   79900.000000            10.000000        2101.000000
# 75%    117100.000000  120950.000000            14.000000       43470.000000
# max    140900.000000  149900.000000            29.000000       95909.000000
#
#        Number Of Reviews  Star Rating
# count          62.000000    62.000000
# mean         1861.677419     4.575806
# std          2855.883830     0.059190
# min            42.000000     4.500000
# 25%            64.000000     4.500000
# 50%           180.000000     4.600000
# ...

# %% [markdown]
# # top 10 iphone highest rated iphones in india

# %%
highest_rated = data.sort_values(by=["Star Rating"],ascending=False)
highest_rated = highest_rated.head(10)

# %%
print(highest_rated["Product Name"])
# Out:
# 20     APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 17         APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 16    APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 15               APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 14              APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 0                    APPLE iPhone 8 Plus (Gold, 64 GB)
# 29                     APPLE iPhone 12 (White, 128 GB)
# 32          APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 35                     APPLE iPhone 12 (Black, 128 GB)
# 36                      APPLE iPhone 12 (Blue, 128 GB)
# Name: Product Name, dtype: object

# %%
print(highest_rated)
# Out:
#                                         Product Name  \
# 20   APPLE iPhone 11 Pro Max (Midnight Green, 64 GB)
# 17       APPLE iPhone 11 Pro Max (Space Grey, 64 GB)
# 16  APPLE iPhone 11 Pro Max (Midnight Green, 256 GB)
# 15             APPLE iPhone 11 Pro Max (Gold, 64 GB)
# 14            APPLE iPhone 11 Pro Max (Gold, 256 GB)
# 0                  APPLE iPhone 8 Plus (Gold, 64 GB)
# 29                   APPLE iPhone 12 (White, 128 GB)
# 32        APPLE iPhone 12 Pro Max (Graphite, 128 GB)
# 35                   APPLE iPhone 12 (Black, 128 GB)
# 36                    APPLE iPhone 12 (Blue, 128 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 20  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 17  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# 16  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      131900
# 15  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117100
# ...

# %% [markdown]
# # How many ratings have highest rated iphones

# %%
iphones =highest_rated["Product Name"].value_counts()
label = iphones.index
counts = highest_rated["Number Of Ratings"]
iphones =highest_rated["Product Name"].value_counts()

label = iphones.index

counts = highest_rated["Number Of Ratings"]
sns.barplot(
    x="Product Name",
    y="Number Of Ratings",
    data=data,
    palette="viridis" # Optional: choose a nice color palette
)

# --- 3. Final Plot Adjustments ---
plt.title("Total Number of Ratings Per iPhone Product", fontsize=12)
plt.xlabel("iPhone Product Name", fontsize=2)
plt.ylabel("Total Number Of Ratings (Sum)", fontsize=2)

# Rotate x-axis labels if product names are long
plt.xticks(rotation=90, ha='right')


plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8744\3661050955.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # iphone has highest numbers of reviews

# %%
iphones =highest_rated["Product Name"].value_counts()
label = iphones.index
counts = highest_rated["Number Of Reviews"]
# figure = plt.bar(highest_rated,x=label, y=counts, title="Number Of Reviews of Highest Rated Iphone")
 # figure.show()

# Use the aligned 'label' and 'counts' from Step 1
plt.figure(figsize=(10, 6))

# Correct usage: x and y data are the first two positional arguments
plt.bar(label, counts)

# Set the title separately
plt.title("Total Number of Ratings Per iPhone Product", fontsize=16)
plt.xlabel("iPhone Product Name", fontsize=12)
plt.ylabel("Total Number Of Ratings (Sum)", fontsize=12)

# Rotate labels for readability
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Correct way to display the plot
plt.show()

# %% [markdown]
# # relationship between sales price of the iphones and the number of ratings

# %%
data.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
# figure1= px.scatter(data_frame=data,x ="Number Of Ratings",y="Sale Price",size="Discount Percentage",trendline="ols",title="Number Of Ratings Vs Sale Price")

 # figure1.show()
 
 # Use the aligned 'label' and 'counts' from Step 1
plt.figure(figsize=(10, 6))

# Correct usage: x and y data are the first two positional arguments
plt.scatter(label, counts)

# Set the title separately
plt.title("Total Number of Ratings Per iPhone Product", fontsize=16)
plt.xlabel("iPhone Product Name", fontsize=12)
plt.ylabel("Total Number Of Ratings (Sum)", fontsize=12)

# Rotate labels for readability
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Correct way to display the plot
plt.show()

# %% [markdown]
# There is negative relationship highest number of reviews having lowest price

# %% [markdown]
# # relationship between discount perventage and number of ratings of iphone

# %%
figure2= px.scatter(data_frame=data,x ="Number Of Ratings",y="Discount Percentage",size="Sale Price",trendline="ols",
           title="Number Of Ratings Vs Discount Percentage")
figure2.show()

# %% [markdown]
# # most expensive and least expensive iphone  with specification

# %%
most_expensive = data.loc[data['Sale Price'].idxmax()]
least_expensive = data.loc[data['Sale Price'].idxmin()]

# Display the result
print("Most expensive product:")
print(most_expensive)

# Display the result
print("\nLeast expensive product:")
print(least_expensive)
# Out:
# Most expensive product:
# Product Name                        APPLE iPhone 12 Pro (Silver, 512 GB)
# Product URL            https://www.flipkart.com/apple-iphone-12-pro-s...
# Brand                                                              Apple
# Sale Price                                                        140900
# Mrp                                                               149900
# Discount Percentage                                                    6
# Number Of Ratings                                                    542
# Number Of Reviews                                                     42
# Upc                                                     MOBFWBYZ5UY6ZBVA
# Star Rating                                                          4.5
# Ram                                                                 4 GB
# Name: 24, dtype: object
#
# Least expensive product:
# Product Name                              APPLE iPhone SE (White, 64 GB)
# ...
