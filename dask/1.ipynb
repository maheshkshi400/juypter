# %%
import dask.dataframe as dd
import numpy as np
images = dd.read_csv(r'C:\Users\User\juypter\files\anscombe.csv')
print(images.head(5))
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
import dask.dataframe as dd
import numpy as np
images = np.ones(10000,1000,1000)
images
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import dask.dataframe as dd
#       2 import numpy as np
# ----> 3 images = np.ones(10000,1000,1000)
#       4 images
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\numeric.py:191, in ones(shape, dtype, order, like)
#     188 if like is not None:
#     189     return _ones_with_like(like, shape, dtype=dtype, order=order)
# --> 191 a = empty(shape, dtype, order)
#     192 multiarray.copyto(a, 1, casting='unsafe')
#     193 return a
#
# TypeError: Cannot interpret '1000' as a data type

# %%
import dask.array as da
images = da.ones(10000,1000,1000)
images
# Out:
# dask.array<ones_like, shape=(10000,), dtype=float64, chunksize=(10000,), chunktype=numpy.ndarray>

# %%
from dask.distributed import Client
from dask_kubernetes import KubeCluster

cluster = KubeCluster()
Client = Client(cluster)
cluster
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 from dask.distributed import Client
# ----> 2 from dask_kubernetes import KubeCluster
#       4 cluster = KubeCluster()
#       5 Client = Client(cluster)
#
# ImportError: cannot import name 'KubeCluster' from 'dask_kubernetes' (c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\dask_kubernetes\__init__.py)

# %%
from dask_kubernetes.operator import KubeCluster

# Create a cluster named 'mycluster'
cluster = KubeCluster(name='mycluster', image='ghcr.io/dask/dask:latest')

# Scale the cluster (e.g., to 5 workers)
cluster.scale(5)

# Connect Dask to the cluster
from dask.distributed import Client
client = Client(cluster)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_transports\default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_transports\default.py:371, in AsyncHTTPTransport.handle_async_request(self, request)
#     370 with map_httpcore_exceptions():
# --> 371     resp = await self._pool.handle_async_request(req)
#     373 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_async\connection_pool.py:216, in AsyncConnectionPool.handle_async_request(self, request)
#     215     await self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_async\connection_pool.py:196, in AsyncConnectionPool.handle_async_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = await connection.handle_async_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_async\connection.py:99, in AsyncHTTPConnection.handle_async_request(self, request)
#      98     self._connect_failed = True
# ---> 99     raise exc
#     101 return await self._connection.handle_async_request(request)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_async\connection.py:76, in AsyncHTTPConnection.handle_async_request(self, request)
#      75 if self._connection is None:
# ---> 76     stream = await self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_async\connection.py:122, in AsyncHTTPConnection._connect(self, request)
#     121 async with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 122     stream = await self._network_backend.connect_tcp(**kwargs)
#     123     trace.return_value = stream
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_backends\auto.py:30, in AutoBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      29 await self._init_backend()
# ---> 30 return await self._backend.connect_tcp(
#      31     host,
#      32     port,
#      33     timeout=timeout,
#      34     local_address=local_address,
#      35     socket_options=socket_options,
#      36 )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_backends\anyio.py:114, in AnyIOBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     109 exc_map = {
#     110     TimeoutError: ConnectTimeout,
#     111     OSError: ConnectError,
#     112     anyio.BrokenResourceError: ConnectError,
#     113 }
# --> 114 with map_exceptions(exc_map):
#     115     with anyio.fail_after(timeout):
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: All connection attempts failed
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[13], line 4
#       1 from dask_kubernetes.operator import KubeCluster
#       3 # Create a cluster named 'mycluster'
# ----> 4 cluster = KubeCluster(name='mycluster', image='ghcr.io/dask/dask:latest')
#       6 # Scale the cluster (e.g., to 5 workers)
#       7 cluster.scale(5)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\dask_kubernetes\operator\kubecluster\kubecluster.py:282, in KubeCluster.__init__(self, name, namespace, image, n_workers, resources, env, worker_command, port_forward_cluster_ip, create_mode, shutdown_on_close, idle_timeout, resource_timeout, scheduler_service_type, custom_cluster_spec, scheduler_forward_port, jupyter, loop, asynchronous, quiet, **kwargs)
#     280 if not called_from_running_loop:
#     281     self._loop_runner.start()
# --> 282     self.sync(self._start)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\distributed\utils.py:358, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     356     return future
#     357 else:
# --> 358     return sync(
#     359         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     360     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\distributed\utils.py:434, in sync(loop, func, callback_timeout, *args, **kwargs)
#     431         wait(10)
#     433 if error is not None:
# --> 434     raise error
#     435 else:
#     436     return result
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\distributed\utils.py:408, in sync.<locals>.f()
#     406         awaitable = wait_for(awaitable, timeout)
#     407     future = asyncio.ensure_future(awaitable)
# --> 408     result = yield future
#     409 except Exception as exception:
#     410     error = exception
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py:767, in Runner.run(self)
#     765 try:
#     766     try:
# --> 767         value = future.result()
#     768     except Exception as e:
#     769         # Save the exception for later. It's important that
#     770         # gen.throw() not be called inside this try/except block
#     771         # because that makes sys.exc_info behave unexpectedly.
#     772         exc: Optional[Exception] = e
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\dask_kubernetes\operator\kubecluster\kubecluster.py:306, in KubeCluster._start(self)
#     304     show_rich_output_task = asyncio.create_task(self._show_rich_output())
#     305 cluster = await DaskCluster(self.name, namespace=self.namespace)
# --> 306 cluster_exists = await cluster.exists()
#     308 if cluster_exists and self.create_mode == CreateMode.CREATE_ONLY:
#     309     raise ValueError(
#     310         f"Cluster {self.name} already exists and create mode is '{CreateMode.CREATE_ONLY}'"
#     311     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\kr8s\_objects.py:238, in APIObject.exists(self, ensure)
#     236 async def exists(self, ensure=False) -> bool:
#     237     """Check if this object exists in Kubernetes."""
# --> 238     return await self.async_exists(ensure=ensure)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\kr8s\_objects.py:243, in APIObject.async_exists(self, ensure)
#     241 """Check if this object exists in Kubernetes."""
#     242 try:
# --> 243     async with self.api.call_api(
#     244         "GET",
#     245         version=self.version,
#     246         url=f"{self.endpoint}/{self.name}",
#     247         namespace=self.namespace,
#     248         raise_for_status=False,
#     249     ) as resp:
#     250         status = resp.status_code
#     251 except ValueError:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:210, in _AsyncGeneratorContextManager.__aenter__(self)
#     208 del self.args, self.kwds, self.func
#     209 try:
# --> 210     return await anext(self.gen)
#     211 except StopAsyncIteration:
#     212     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\kr8s\_api.py:143, in Api.call_api(self, method, version, base, namespace, url, raise_for_status, stream, **kwargs)
#     141         yield response
#     142 else:
# --> 143     response = await self._session.request(**kwargs)
#     144     if raise_for_status:
#     145         response.raise_for_status()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1559, in AsyncClient.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1530 """
#    1531 Build and send a request.
#    1532
#    (...)
#    1544 [0]: /advanced/#merging-of-configuration
#    1545 """
#    1546 request = self.build_request(
#    1547     method=method,
#    1548     url=url,
#    (...)
#    1557     extensions=extensions,
#    1558 )
# -> 1559 return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1646, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1638 follow_redirects = (
#    1639     self.follow_redirects
#    1640     if isinstance(follow_redirects, UseClientDefault)
#    1641     else follow_redirects
#    1642 )
#    1644 auth = self._build_request_auth(request, auth)
# -> 1646 response = await self._send_handling_auth(
#    1647     request,
#    1648     auth=auth,
#    1649     follow_redirects=follow_redirects,
#    1650     history=[],
#    1651 )
#    1652 try:
#    1653     if not stream:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1674, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1671 request = await auth_flow.__anext__()
#    1673 while True:
# -> 1674     response = await self._send_handling_redirects(
#    1675         request,
#    1676         follow_redirects=follow_redirects,
#    1677         history=history,
#    1678     )
#    1679     try:
#    1680         try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1711, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1708 for hook in self._event_hooks["request"]:
#    1709     await hook(request)
# -> 1711 response = await self._send_single_request(request)
#    1712 try:
#    1713     for hook in self._event_hooks["response"]:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1748, in AsyncClient._send_single_request(self, request)
#    1743     raise RuntimeError(
#    1744         "Attempted to send an sync request with an AsyncClient instance."
#    1745     )
#    1747 with request_context(request=request):
# -> 1748     response = await transport.handle_async_request(request)
#    1750 assert isinstance(response.stream, AsyncByteStream)
#    1751 response.request = request
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_transports\default.py:370, in AsyncHTTPTransport.handle_async_request(self, request)
#     356 assert isinstance(request.stream, AsyncByteStream)
#     358 req = httpcore.Request(
#     359     method=request.method,
#     360     url=httpcore.URL(
#    (...)
#     368     extensions=request.extensions,
#     369 )
# --> 370 with map_httpcore_exceptions():
#     371     resp = await self._pool.handle_async_request(req)
#     373 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_transports\default.py:84, in map_httpcore_exceptions()
#      81     raise
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# ConnectError: All connection attempts failed

# %%
from dask_kubernetes.operator import KubeCluster, make_cluster_spec

config = {
    "name": "foo",
    "n_workers": 2,
    "resources": {
        "requests": {"memory": "2Gi"},
        "limits": {"memory": "64Gi"}
    }
}

# Create the cluster
cluster = KubeCluster(custom_cluster_spec=make_cluster_spec(**config))
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_transports\default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_transports\default.py:371, in AsyncHTTPTransport.handle_async_request(self, request)
#     370 with map_httpcore_exceptions():
# --> 371     resp = await self._pool.handle_async_request(req)
#     373 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_async\connection_pool.py:216, in AsyncConnectionPool.handle_async_request(self, request)
#     215     await self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_async\connection_pool.py:196, in AsyncConnectionPool.handle_async_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = await connection.handle_async_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_async\connection.py:99, in AsyncHTTPConnection.handle_async_request(self, request)
#      98     self._connect_failed = True
# ---> 99     raise exc
#     101 return await self._connection.handle_async_request(request)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_async\connection.py:76, in AsyncHTTPConnection.handle_async_request(self, request)
#      75 if self._connection is None:
# ---> 76     stream = await self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_async\connection.py:122, in AsyncHTTPConnection._connect(self, request)
#     121 async with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 122     stream = await self._network_backend.connect_tcp(**kwargs)
#     123     trace.return_value = stream
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_backends\auto.py:30, in AutoBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      29 await self._init_backend()
# ---> 30 return await self._backend.connect_tcp(
#      31     host,
#      32     port,
#      33     timeout=timeout,
#      34     local_address=local_address,
#      35     socket_options=socket_options,
#      36 )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_backends\anyio.py:114, in AnyIOBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     109 exc_map = {
#     110     TimeoutError: ConnectTimeout,
#     111     OSError: ConnectError,
#     112     anyio.BrokenResourceError: ConnectError,
#     113 }
# --> 114 with map_exceptions(exc_map):
#     115     with anyio.fail_after(timeout):
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: All connection attempts failed
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[14], line 13
#       3 config = {
#       4     "name": "foo",
#       5     "n_workers": 2,
#    (...)
#       9     }
#      10 }
#      12 # Create the cluster
# ---> 13 cluster = KubeCluster(custom_cluster_spec=make_cluster_spec(**config))
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\dask_kubernetes\operator\kubecluster\kubecluster.py:282, in KubeCluster.__init__(self, name, namespace, image, n_workers, resources, env, worker_command, port_forward_cluster_ip, create_mode, shutdown_on_close, idle_timeout, resource_timeout, scheduler_service_type, custom_cluster_spec, scheduler_forward_port, jupyter, loop, asynchronous, quiet, **kwargs)
#     280 if not called_from_running_loop:
#     281     self._loop_runner.start()
# --> 282     self.sync(self._start)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\distributed\utils.py:358, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     356     return future
#     357 else:
# --> 358     return sync(
#     359         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     360     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\distributed\utils.py:434, in sync(loop, func, callback_timeout, *args, **kwargs)
#     431         wait(10)
#     433 if error is not None:
# --> 434     raise error
#     435 else:
#     436     return result
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\distributed\utils.py:408, in sync.<locals>.f()
#     406         awaitable = wait_for(awaitable, timeout)
#     407     future = asyncio.ensure_future(awaitable)
# --> 408     result = yield future
#     409 except Exception as exception:
#     410     error = exception
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tornado\gen.py:767, in Runner.run(self)
#     765 try:
#     766     try:
# --> 767         value = future.result()
#     768     except Exception as e:
#     769         # Save the exception for later. It's important that
#     770         # gen.throw() not be called inside this try/except block
#     771         # because that makes sys.exc_info behave unexpectedly.
#     772         exc: Optional[Exception] = e
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\dask_kubernetes\operator\kubecluster\kubecluster.py:306, in KubeCluster._start(self)
#     304     show_rich_output_task = asyncio.create_task(self._show_rich_output())
#     305 cluster = await DaskCluster(self.name, namespace=self.namespace)
# --> 306 cluster_exists = await cluster.exists()
#     308 if cluster_exists and self.create_mode == CreateMode.CREATE_ONLY:
#     309     raise ValueError(
#     310         f"Cluster {self.name} already exists and create mode is '{CreateMode.CREATE_ONLY}'"
#     311     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\kr8s\_objects.py:238, in APIObject.exists(self, ensure)
#     236 async def exists(self, ensure=False) -> bool:
#     237     """Check if this object exists in Kubernetes."""
# --> 238     return await self.async_exists(ensure=ensure)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\kr8s\_objects.py:243, in APIObject.async_exists(self, ensure)
#     241 """Check if this object exists in Kubernetes."""
#     242 try:
# --> 243     async with self.api.call_api(
#     244         "GET",
#     245         version=self.version,
#     246         url=f"{self.endpoint}/{self.name}",
#     247         namespace=self.namespace,
#     248         raise_for_status=False,
#     249     ) as resp:
#     250         status = resp.status_code
#     251 except ValueError:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:210, in _AsyncGeneratorContextManager.__aenter__(self)
#     208 del self.args, self.kwds, self.func
#     209 try:
# --> 210     return await anext(self.gen)
#     211 except StopAsyncIteration:
#     212     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\kr8s\_api.py:143, in Api.call_api(self, method, version, base, namespace, url, raise_for_status, stream, **kwargs)
#     141         yield response
#     142 else:
# --> 143     response = await self._session.request(**kwargs)
#     144     if raise_for_status:
#     145         response.raise_for_status()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1559, in AsyncClient.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1530 """
#    1531 Build and send a request.
#    1532
#    (...)
#    1544 [0]: /advanced/#merging-of-configuration
#    1545 """
#    1546 request = self.build_request(
#    1547     method=method,
#    1548     url=url,
#    (...)
#    1557     extensions=extensions,
#    1558 )
# -> 1559 return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1646, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1638 follow_redirects = (
#    1639     self.follow_redirects
#    1640     if isinstance(follow_redirects, UseClientDefault)
#    1641     else follow_redirects
#    1642 )
#    1644 auth = self._build_request_auth(request, auth)
# -> 1646 response = await self._send_handling_auth(
#    1647     request,
#    1648     auth=auth,
#    1649     follow_redirects=follow_redirects,
#    1650     history=[],
#    1651 )
#    1652 try:
#    1653     if not stream:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1674, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1671 request = await auth_flow.__anext__()
#    1673 while True:
# -> 1674     response = await self._send_handling_redirects(
#    1675         request,
#    1676         follow_redirects=follow_redirects,
#    1677         history=history,
#    1678     )
#    1679     try:
#    1680         try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1711, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1708 for hook in self._event_hooks["request"]:
#    1709     await hook(request)
# -> 1711 response = await self._send_single_request(request)
#    1712 try:
#    1713     for hook in self._event_hooks["response"]:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1748, in AsyncClient._send_single_request(self, request)
#    1743     raise RuntimeError(
#    1744         "Attempted to send an sync request with an AsyncClient instance."
#    1745     )
#    1747 with request_context(request=request):
# -> 1748     response = await transport.handle_async_request(request)
#    1750 assert isinstance(response.stream, AsyncByteStream)
#    1751 response.request = request
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_transports\default.py:370, in AsyncHTTPTransport.handle_async_request(self, request)
#     356 assert isinstance(request.stream, AsyncByteStream)
#     358 req = httpcore.Request(
#     359     method=request.method,
#     360     url=httpcore.URL(
#    (...)
#     368     extensions=request.extensions,
#     369 )
# --> 370 with map_httpcore_exceptions():
#     371     resp = await self._pool.handle_async_request(req)
#     373 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_transports\default.py:84, in map_httpcore_exceptions()
#      81     raise
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# ConnectError: All connection attempts failed
