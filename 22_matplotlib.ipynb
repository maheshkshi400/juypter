# %%
import matplotlib.pyplot as plt
import numpy as np

w=0.3

x=[8,12,11,27,20,43,32,21,10,21,
   41,63,90,51,30,75,80,23,36,51,
   31,9,6,43,56,91,32,46,57,67,
   81,71,61,40,52,47,58,83,90,21,
   71,45,23,52,65,32,35,56,27,56,
   31,89,43,30,51,21,11,65,75,89]

y =[11,21,31,41,51,61,71,81,91,101]

plt.hist(x,"auto",color="pink",ec="red",bottom=10,histtype="step")



plt.xlabel("age")
plt.ylabel("counts")
plt.title("Population age count")
plt.xticks(y)


plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
