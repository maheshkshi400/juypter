# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import seaborn as sns
#       2 sns.get_dataset_names()
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

var = [1,2,3,4,5,6,7]
var_1= [2,3,4,6,7,8,9]

x_1 = pd.DataFrame({"var":var,"var_1":var_1})

sns.lineplot(x="var",y="var_1",data=x_1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
var = [1,2,3,4,5,6,7]
var_1= [2,3,4,6,7,8,9]



sns.lineplot(x=var,y=var_1)

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


technologies = {
    'Courses':["Spark","PySpark","Hadoop","Python","pandas","Oracle","Java"],
    'Fee' :[20000,25000,26000,22000,24000,21000,22000],
    'Duration':['30days','40days','35days','40days',np.nan,None,'55days'],
    'Discount':[1000,2300,1500,1200,2500,2100,2000]
               }
index_labels=['r1','r2','r3','r4','r5','r6','r7']
df = pd.DataFrame(technologies,index=index_labels)
print(df)
# Out:
#     Courses    Fee Duration  Discount
# r1    Spark  20000   30days      1000
# r2  PySpark  25000   40days      2300
# r3   Hadoop  26000   35days      1500
# r4   Python  22000   40days      1200
# r5   pandas  24000      NaN      2500
# r6   Oracle  21000     None      2100
# r7     Java  22000   55days      2000

# %%
Courses=["Spark","PySpark","Hadoop","Python","pandas","Oracle","Java"]
Fee = [20000,25000,26000,22000,24000,21000,22000]

sns.lineplot(x=Courses,y=Fee)
                   
plt.show()

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder.appName("https://github.com/maheshkshi400/MK").getOrCreate()



data1 = [(1,'mahesh','kshirsagar','male',20,5000,'IT',50,2002),
         (2,'shruthi','kachave','female',30,6000,'HR',20,2008),
         (3,'ganesh','kenjale','male',25,7000,'FINANCE',30,2010),
         (4,'pooja','bhate','female',34,8000,'PAYROLL',40,2005),
         (5,'kamini','kadam','female',31,6000,'IT',None,2007),
         (6,'shivaji','nemade','male',20,8000,'IT',50,1004),
         (7,'shweta','lakhani','female',30,6000,'HR',20,1998),
         (8,'suresh','kirve','male',25,10000,'FINANCE',30,2011),
         (9,'shivani','jagtap',None,34,11000,'PAYROLL',40,2013),
         (10,'prachi','inamdar','female',30,6000,'IT',50,2001)]

schema1 = ['id','f_name','l_name','gender','age','salary','dept','deptno','doj']

empdf = spark.createDataFrame(data1,schema1)

empdf.show()

pandas_empdf=empdf.toPandas()
pandas_empdf
# Out:
# +---+-------+----------+------+---+------+-------+------+----+
# | id| f_name|    l_name|gender|age|salary|   dept|deptno| doj|
# +---+-------+----------+------+---+------+-------+------+----+
# |  1| mahesh|kshirsagar|  male| 20|  5000|     IT|    50|2002|
# |  2|shruthi|   kachave|female| 30|  6000|     HR|    20|2008|
# |  3| ganesh|   kenjale|  male| 25|  7000|FINANCE|    30|2010|
# |  4|  pooja|     bhate|female| 34|  8000|PAYROLL|    40|2005|
# |  5| kamini|     kadam|female| 31|  6000|     IT|  NULL|2007|
# |  6|shivaji|    nemade|  male| 20|  8000|     IT|    50|1004|
# |  7| shweta|   lakhani|female| 30|  6000|     HR|    20|1998|
# |  8| suresh|     kirve|  male| 25| 10000|FINANCE|    30|2011|
# |  9|shivani|    jagtap|  NULL| 34| 11000|PAYROLL|    40|2013|
# | 10| prachi|   inamdar|female| 30|  6000|     IT|    50|2001|
# +---+-------+----------+------+---+------+-------+------+----+
#    id   f_name      l_name  gender  age  salary     dept  deptno   doj
# ...

# %%
sns.lineplot(x="f_name",y="salary",data=pandas_empdf,hue="dept")
                   
plt.show()

# %%
sns.lineplot(x="f_name",y="salary",data=pandas_empdf,hue="gender",size=50,style="dept",palette="Accent")
                   
plt.show()

# %%
sns.lineplot(x="f_name",y="salary",data=pandas_empdf,hue="gender",size=50,style="dept",palette="autumn")
                   
plt.show()

# %%
sns.lineplot(x="f_name",y="salary",data=pandas_empdf,hue="gender",size=50,style="dept",palette='Accent',markers=["o",">"],dashes=False)
                   
plt.show()
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_14492\55235424.py:1: UserWarning:
# The markers list has fewer values (2) than needed (4) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(x="f_name",y="salary",data=pandas_empdf,hue="gender",size=50,style="dept",palette='Accent',markers=["o",">"],dashes=False)

# %%
sns.lineplot(x="f_name",y="salary",data=pandas_empdf,hue="gender",dashes=False,legend="full")
plt.grid()
plt.title("employee_salary")
plt.show()
