# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
var= pd.read_csv(r'C:\Users\User\juypter\files\tips.csv')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x="size",y="tip",data=var,palette="terrain",edgecolor="r",kind="bar")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4500\4242722641.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="size",y="tip",data=var,palette="terrain",edgecolor="r",kind="bar")

# %%
sns.catplot(x="size",y="tip",data=var,palette="terrain_r",edgecolor="r",kind="swarm")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4500\4202254773.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="size",y="tip",data=var,palette="terrain_r",edgecolor="r",kind="swarm")
# C:\Users\User\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 31.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 37.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="tip",y="size",data=var,palette="terrain_r",edgecolor="r",kind="bar",hue="sex")
plt.show()

# %%
sns.catplot(x="tip",y="size",data=var,palette="Oranges_r",kind="boxen",hue="sex")
plt.show()
