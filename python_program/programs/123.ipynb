# %%
l = [1, 'a', 3, 'b', 4, 'c']
output_list = []

for i in l:
    if isinstance(i, int):
        output_list.append(i)

print(output_list)
# Out:
# [1, 3, 4]

# %%
l = [1, 'a', 3, 'b', 4, 'c']

for int in l:
    print(int)
# Out:
# 1
# a
# 3
# b
# 4
# c

# %%
lnput_list= [1,a,3,b,4,c]
 

# output = [1,3,4]

for i in range(l):
	v= isinstance(int,lnput_list):
