# %%
import yfinance as yf
import datetime
import plotly.graph_objects as go
update_interval =60

ticker = yf.Ticker("RELIANCE.NS")
data = yf.download(ticker ,start="2014-1-1",end="2024-12-31",uodate_interval=1)



fig = go.Figure(data=[go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'],
                increasing_line_color='green',
                decreasing_line_color='red')])

fig.update_layout(
    title=f"{ticker} stock price (live)",
    xaxis_title="Date",
    yaxis_title="Stock price(INR)",
    xaxis_rangeslider_visible=False
)

fig.show()
# Out:
#   Cell In[5], line 7
#     data = yf.download(ticker ,start="2014-1-1",end="2024-12-31",uodate_interval=1s)
#                                                                                  ^
# SyntaxError: invalid decimal literal

# %%
import yfinance as yf
import plotly.graph_objects as go

# Define the ticker symbol before using it
ticker =input("Enter the stock  name: ")  # Replace "AAPL" with the desired stock symbol "AAPL"  # Replace "AAPL" with the desired stock symbol

data = yf.download(ticker, start="2014-1-1", end="2024-12-31")

fig = go.Figure(data=[go.Candlestick(x=data.index,
                                     open=data['Open'],
                                     high=data['High'],
                                     low=data['Low'],
                                     close=data['Close'],
                                     increasing_line_color='green',
                                     decreasing_line_color='red')])

fig.update_layout(
    title=f"{ticker} stock price (2023)",
    xaxis_title="Date",
    yaxis_title="Stock price(INR)",
    xaxis_rangeslider_visible=False
)

fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import datetime
update_interval = 60 # seconds

while True:
  # Download data
  data = yf.download(ticker, start=datetime.datetime.today()-datetime.timedelta(days=1), end=datetime.datetime.today())

  # Update the figure with new data
  fig.data[0].x = data.index
  fig.data[0].open = data['Open']
  fig.data[0].high = data['High']
  fig.data[0].low = data['Low']
  fig.data[0].close = data['Close']

  # Update the layout (optional)
  fig.update_layout(title=f"{ticker} stock price (Live)")

  # Display the updated figure
  fig.show()

  # Wait before next update
  time.sleep(update_interval)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
import periodictable

# Function to get information about an element
def get_element_info(symbol):
    # Check if the symbol is valid
    if not periodictable.elements.symbol(symbol):
        print("Invalid element symbol.")
        return

    # Access information about the specified element
    element = periodictable.elements.symbol(symbol)

    # Print information about the element
    print(f"Element: {element.name}")
    print(f"Symbol: {element.symbol}")
    print(f"Atomic Number: {element.number}")
    print(f"Atomic Weight: {element.mass}")
    print(f"Density: {element.density}")

# Prompt the user to input an element symbol
element_symbol = input("Enter the symbol of the element: ")

# Call the function to get information about the specified element
get_element_info(element_symbol)
