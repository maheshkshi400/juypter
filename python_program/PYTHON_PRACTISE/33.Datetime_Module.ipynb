# %%
import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2025-09-26 18:06:27.945291

# %%
x = datetime.datetime(2027,2,18)
print(x)
# Out:
# 2027-02-18 00:00:00

# %%
# strftime

x = datetime.datetime.now()
m = x.strftime("%Y-%m-%d %H:%M:%S")

m = x.strftime("%H:%M:%S %p")

m = x.strftime("%b")

print(m)
# Out:
# Sep

# %%
m = x.strftime("%H:%M:%S %p")
print(m)
# Out:
# 18:06:49 PM

# %%
m = x.strftime("%b")
print(m)
# Out:
# Sep

# %%
m = x.strftime("%I")
print(m)
# Out:
# 06
