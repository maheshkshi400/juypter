# %%
l= [10,20,30,40,50]

# %%
del l[2]
print(l)
# Out:
# [10, 20, 40, 50]

# %%
l.pop(2)
print(l)
# Out:
# [10, 20, 50]

# %%
print(l.pop(1))
print(l)
# Out:
# 20
# [10]

# %%
l= [10,20,30,40,50]

l.remove(10)
print(l)
# Out:
# [20, 30, 40, 50]

# %%
l= [10,20,30,40,50]

l.clear()
print(l)
# Out:
# []

# %%
# update list

l = [20,30,40,50]
l[0]=90
print(l)
# Out:
# [90, 30, 40, 50]

# %%
# insert element the list

l = [1, 2, 3, 4, 5]
l.insert(2, 10)
print(l)
# Out:
# [1, 2, 10, 3, 4, 5]

# %%
# append element in the list

l = [30,40,60,70,90]

l.append(100)
print(l)
# Out:
# [30, 40, 60, 70, 90, 100]

# %%
l = [30,40,60,70,90]
v = [10,30,40]
l.extend(v)
print(l)
# Out:
# [30, 40, 60, 70, 90, 10, 30, 40]
