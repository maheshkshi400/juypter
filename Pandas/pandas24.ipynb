# %%
pip install "snowflake-connector-python[pandas]"
# Out:
# ...
#   Using cached snowflake_connector_python-3.10.0-cp312-cp312-win_amd64.whl.metadata (63 kB)
# ...
#   Using cached asn1crypto-1.5.1-py2.py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached cryptography-42.0.5-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached pyOpenSSL-24.1.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached tomlkit-0.12.4-py3-none-any.whl.metadata (2.7 kB)
# ...
# Using cached asn1crypto-1.5.1-py2.py3-none-any.whl (105 kB)
# Using cached cryptography-42.0.5-cp39-abi3-win_amd64.whl (2.9 MB)
# Using cached filelock-3.14.0-py3-none-any.whl (12 kB)
# Using cached PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Using cached pyOpenSSL-24.1.0-py3-none-any.whl (56 kB)
# ...

# %%
from snowflake.connector.pandas_tools import write_pandas
import snowflake.connector
import pandas as pd
import os

# %%
data = pd.read_csv('C:/Users/User/juypter/files/empdf.CSV')
data
# Out:
#    id     name  gender   age   salary     dept  deptno   doj
# 0   1   mahesh    male  20.0   5000.0       IT    50.0  2002
# 1   2  shruthi  female   NaN   6000.0       HR    20.0  2008
# 2   3   ganesh    male  25.0      NaN  FINANCE    30.0  2010
# 3   4    pooja  female   NaN   8000.0  PAYROLL    40.0  2005
# 4   5   kamini  female  31.0   6000.0       IT    50.0  2007
# 5   6   mukesh     NaN  32.0   7000.0      NaN     NaN  2011
# 6   7   shweta  female  30.0   6000.0       HR    20.0  1998
# 7   8   suresh    male  25.0  10000.0  FINANCE    30.0  2011
# 8   9  shivani  female  34.0      NaN  PAYROLL    40.0  2013
# 9  10   prachi  female  30.0   6000.0       IT    50.0  2001

# %%
import os
os.getcwd()  # Outputs the current working directory
# Out:
# 'e:\\juypter\\Pandas'

# %%
con = snowflake.connector.connect(
    user='maheshkshi400',
    password='Mahadev@9096',
    account='qjlfekd-cy75296',
    warehouse='COMPUTE_WH',
    database='DEPARTMENT',
    schema='PUBLIC',
    role='ACCOUNTADMIN'
)

# %%
cur= con.cursor()

# %%
data.columns
# Out:
# Index(['id', 'name', 'gender', 'age', 'salary', 'dept', 'deptno', 'doj'], dtype='object')

# %%
cur.execute("USE DATABASE SNOWFLAKE;")

# %%
cur.execute('CREATE TABLE "EMP"("ID" int,"NAME" string,"GENDER" string,"age" int,"SALARY" int,"DEPT" string,"DEPTNO" int,"DOJ" DATE )')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 cur.execute('CREATE TABLE "EMP"("ID" int,"NAME" string,"GENDER" string,"age" int,"SALARY" int,"DEPT" string,"DEPTNO" int,"DOJ" DATE )')
#
# File c:\Program Files\Python312\Lib\site-packages\snowflake\connector\cursor.py:1080, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#    1076     is_integrity_error = (
#    1077         code == "100072"
#    1078     )  # NULL result in a non-nullable column
# ...

# %%
cur.execute("USE DATABASE SNOWFLAKE;")
cur.execute("CREATE SCHEMA EMPLOYEE;")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[18], line 2
#       1 cur.execute("USE DATABASE SNOWFLAKE;")
# ----> 2 cur.execute("CREATE SCHEMA EMPLOYEE;")
#
# File c:\Program Files\Python312\Lib\site-packages\snowflake\connector\cursor.py:1080, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#    1076     is_integrity_error = (
#    1077         code == "100072"
#    1078     )  # NULL result in a non-nullable column
# ...

# %%
import great_expectations as ge
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\User\juypter\files\anagrams.csv')
df
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
my_df = ge.from_pandas(df)
my_df
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
my_df.expect_table_row_count_to_equal(25)
# Out:
# {
#   "success": false,
#   "result": {
#     "observed_value": 20
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %%
my_df.except_column_to_exist('num3')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9624\1658914151.py in ?()
# ----> 1 my_df.except_column_to_exist('num3')
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'PandasDataset' object has no attribute 'except_column_to_exist'

# %%
from pendulum import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pendulum import datetime
#
# ModuleNotFoundError: No module named 'pendulum'
