# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv(r'E:\juypter\files\empdf12.CSV')
sns.barplot(x="name",y="salary",data=df)
# Out:
# <Axes: xlabel='name', ylabel='salary'>

# %%
df.fillna(12,inplace=True)
df
# Out:
#    id               name  gender   age   salary     dept  deptno        doj
# 0   1  Mahesh Kshirsagar    male  20.0   5000.0       IT    50.0  19-4-2011
# 1   2     Shruthi Sharma  female  12.0   6000.0       HR    12.0  20-5-2007
# 2   3     Ganesh Kenjale    male  25.0     12.0  FINANCE    30.0         12
# 3   4      Pooja Chandra  female  12.0   8000.0  PAYROLL    40.0  14-4-1998
# 4   5       kamini sinha  female  31.0   6000.0       IT    50.0  20-5-2002
# 5   6          Rahul Roy      12  28.0     12.0       12    10.0  31-8-2015
# 6   7      Shweta Tiwari  female  30.0   6000.0       HR    20.0         12
# 7   8     suresh Katwani      12  25.0  10000.0  FINANCE    30.0  22-3-2007
# 8   9                 12      12  12.0     12.0       12    12.0         12
# 9  10     prachi Inamdar  female  30.0   6000.0       12    50.0         12

# %%
df.fillna("python",limit=13)
# Out:
#    id               name  gender   age   salary     dept  deptno        doj
# 0   1  Mahesh Kshirsagar    male  20.0   5000.0       IT    50.0  19-4-2011
# 1   2     Shruthi Sharma  female  12.0   6000.0       HR    12.0  20-5-2007
# 2   3     Ganesh Kenjale    male  25.0     12.0  FINANCE    30.0         12
# 3   4      Pooja Chandra  female  12.0   8000.0  PAYROLL    40.0  14-4-1998
# 4   5       kamini sinha  female  31.0   6000.0       IT    50.0  20-5-2002
# 5   6          Rahul Roy      12  28.0     12.0       12    10.0  31-8-2015
# 6   7      Shweta Tiwari  female  30.0   6000.0       HR    20.0         12
# 7   8     suresh Katwani      12  25.0  10000.0  FINANCE    30.0  22-3-2007
# 8   9                 12      12  12.0     12.0       12    12.0         12
# 9  10     prachi Inamdar  female  30.0   6000.0       12    50.0         12

# %%
df.fillna(method='bfill',axis=1)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6448\3381026564.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',axis=1)
# C:\Users\User\AppData\Local\Temp\ipykernel_6448\3381026564.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(method='bfill',axis=1)
#     id               name  gender   age   salary     dept deptno        doj
# 0    1  Mahesh Kshirsagar    male  20.0   5000.0       IT   50.0  19-4-2011
# 1    2     Shruthi Sharma  female  12.0   6000.0       HR   12.0  20-5-2007
# 2    3     Ganesh Kenjale    male  25.0     12.0  FINANCE   30.0         12
# 3    4      Pooja Chandra  female  12.0   8000.0  PAYROLL   40.0  14-4-1998
# 4    5       kamini sinha  female  31.0   6000.0       IT   50.0  20-5-2002
# 5    6          Rahul Roy      12  28.0     12.0       12   10.0  31-8-2015
# 6    7      Shweta Tiwari  female  30.0   6000.0       HR   20.0         12
# 7    8     suresh Katwani      12  25.0  10000.0  FINANCE   30.0  22-3-2007
# 8  9.0               12.0    12.0  12.0     12.0     12.0   12.0       12.0
# 9   10     prachi Inamdar  female  30.0   6000.0       12   50.0         12

# %%
df.fillna({"name":"unnamed","gender":"unknown","salary":"NA"})
# Out:
#    id               name  gender   age   salary     dept  deptno        doj
# 0   1  Mahesh Kshirsagar    male  20.0   5000.0       IT    50.0  19-4-2011
# 1   2     Shruthi Sharma  female  12.0   6000.0       HR    12.0  20-5-2007
# 2   3     Ganesh Kenjale    male  25.0     12.0  FINANCE    30.0         12
# 3   4      Pooja Chandra  female  12.0   8000.0  PAYROLL    40.0  14-4-1998
# 4   5       kamini sinha  female  31.0   6000.0       IT    50.0  20-5-2002
# 5   6          Rahul Roy      12  28.0     12.0       12    10.0  31-8-2015
# 6   7      Shweta Tiwari  female  30.0   6000.0       HR    20.0         12
# 7   8     suresh Katwani      12  25.0  10000.0  FINANCE    30.0  22-3-2007
# 8   9                 12      12  12.0     12.0       12    12.0         12
# 9  10     prachi Inamdar  female  30.0   6000.0       12    50.0         12

# %%
df.fillna(method='ffill')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6448\1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#    id               name  gender   age   salary     dept  deptno        doj
# 0   1  Mahesh Kshirsagar    male  20.0   5000.0       IT    50.0  19-4-2011
# 1   2     Shruthi Sharma  female  12.0   6000.0       HR    12.0  20-5-2007
# 2   3     Ganesh Kenjale    male  25.0     12.0  FINANCE    30.0         12
# 3   4      Pooja Chandra  female  12.0   8000.0  PAYROLL    40.0  14-4-1998
# 4   5       kamini sinha  female  31.0   6000.0       IT    50.0  20-5-2002
# 5   6          Rahul Roy      12  28.0     12.0       12    10.0  31-8-2015
# 6   7      Shweta Tiwari  female  30.0   6000.0       HR    20.0         12
# 7   8     suresh Katwani      12  25.0  10000.0  FINANCE    30.0  22-3-2007
# 8   9                 12      12  12.0     12.0       12    12.0         12
# 9  10     prachi Inamdar  female  30.0   6000.0       12    50.0         12

# %%
df.fillna(method='bfill')
# Out:
#      id     name  gender   age   salary     dept  deptno     doj
# 0   1.0   mahesh    male  20.0   5000.0       IT    50.0  2002.0
# 1   2.0  shruthi  female  25.0   6000.0       HR    20.0  2008.0
# 2   3.0   ganesh    male  25.0   7000.0  FINANCE    30.0  2010.0
# 3   4.0    pooja  female  31.0   8000.0  PAYROLL    40.0  2005.0
# 4   5.0   kamini  female  31.0   6000.0       IT    50.0  2007.0
# 5   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 6   7.0   shweta  female  30.0   6000.0       HR    20.0  1998.0
# 7   8.0   suresh    male  25.0  10000.0  FINANCE    30.0  2011.0
# 8   9.0  shivani  female  34.0   6000.0  PAYROLL    40.0  2013.0
# 9  10.0   prachi  female  30.0   6000.0       IT    50.0  2001.0
